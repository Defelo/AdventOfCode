# %%
import sys; sys.path.insert(0, "..")

from utils import *
import aoc

year, day = 2021, 7

puzzle = aoc.setup(year, day)
plines = puzzle.splitlines()
# Out:
# # Day 07

# %% [markdown]
# ### Puzzle 1

# %%
def solve1():
    nums = [*map(int, puzzle.split(","))]
    def align(pos):
        return sum(
            abs(n - pos)
            for n in nums
        )
    return min(map(align, range(len(nums))))

solve1()
# Out:
# 340052

# %%
# %timeit solve1()
# Out:
# 103 ms ± 2.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
(lambda N=[*map(int,puzzle.split(","))]:min(sum(abs(n-p)for n in N)for p in range(len(N))))()
# Out:
# 340052

# %% [markdown]
# ### Puzzle 2

# %%
def solve2():
    nums = [*map(int, puzzle.split(","))]
    def align(pos):
        return sum(
            (x := abs(n - pos)) * (x+1) // 2
            for n in nums
        )
    return min(map(align, range(len(nums))))

solve2()
# Out:
# 92948968

# %%
# %timeit solve2()
# Out:
# 198 ms ± 3.89 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
(lambda N=[*map(int,puzzle.split(","))]:min(sum((x:=abs(n-p))*(x+1)//2for n in N)for p in range(len(N))))()
# Out:
# 92948968
