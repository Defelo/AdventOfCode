# %%
import sys; sys.path.insert(0, "..")

from utils import *
import aoc

year, day = 2021, 6

puzzle = aoc.setup(year, day)
plines = puzzle.splitlines()
# Out:
# # Day 06

# %% [markdown]
# ### Puzzle 1

# %%
def solve1():
    nums = [*map(int, puzzle.split(","))]
    nums = [*map(nums.count, range(9))]
    for _ in range(80):
        nums.append(x := nums.pop(0))
        nums[6] += x
    return sum(nums)

solve1()
# Out:
# 345793

# %%
# %timeit solve1()
# Out:
# 207 µs ± 48.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
(lambda N=[*map([*map(int,puzzle.split(","))].count, range(9))]:sum([(N.append(x:=N.pop(0)),N.__setitem__(6,N[6]+x))for _ in range(80)]and N))()
# Out:
# 345793

# %% [markdown]
# ### Puzzle 2

# %%
def solve2():
    nums = [*map(int, puzzle.split(","))]
    nums = [*map(nums.count, range(9))]
    for _ in range(256):
        nums.append(x := nums.pop(0))
        nums[6] += x
    return sum(nums)

solve2()
# Out:
# 1572643095893

# %%
# %timeit solve2()
# Out:
# 315 µs ± 66.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
(lambda N=[*map([*map(int,puzzle.split(","))].count, range(9))]:sum([(N.append(x:=N.pop(0)),N.__setitem__(6,N[6]+x))for _ in range(256)]and N))()
# Out:
# 1572643095893
